# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('C:/Users/DELL/Downloads/Working Data.xlsx')
df
# Out:
#               SKU                 Date          Complete Date  order_type   \
# 0       A0FA966A7  2021-01-04 09:27:00   1/4/2021 10:58:59:653    Delivery
# 1       A0F2AF467  2021-01-04 09:21:00    1/4/2021 10:59:00:19    Delivery
# 2       A07392036  2021-01-04 09:19:00    1/4/2021 10:59:00:56    Delivery
# 3       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# 4       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# ...           ...                  ...                     ...         ...
# 479302  A0F205096  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479303  A0F205094  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479304  A0F205093  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479305  A0F2F6435  2022-07-28 13:48:00   7/29/2022 18:54:48:46    Delivery
# 479306  A0F240576  2022-07-27 10:36:00  7/29/2022 18:54:56:547    Delivery
#
#         In_Qty  Out_Qty   Order No  Location
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.shape
# Out:
# (479307, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479307 entries, 0 to 479306
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SKU             279038 non-null  object
#  1   Date            279038 non-null  object
#  2   Complete Date   279038 non-null  object
#  3   order_type      279038 non-null  object
#  4   In_Qty          279038 non-null  float64
#  5   Out_Qty         279038 non-null  float64
#  6   Order No        277070 non-null  object
#  7   Location        279038 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 29.3+ MB

# %%
df1 =  df

# %%
df1.isna().sum()
# Out:
# SKU               200269
# Date              200269
# Complete Date     200269
# order_type        200269
# In_Qty            200269
# Out_Qty           200269
# Order No          202237
# Location          200269
# dtype: int64

# %%
df1.dropna()
# Out:
#               SKU                 Date          Complete Date  order_type   \
# 0       A0FA966A7  2021-01-04 09:27:00   1/4/2021 10:58:59:653    Delivery
# 1       A0F2AF467  2021-01-04 09:21:00    1/4/2021 10:59:00:19    Delivery
# 2       A07392036  2021-01-04 09:19:00    1/4/2021 10:59:00:56    Delivery
# 3       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# 4       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# ...           ...                  ...                     ...         ...
# 479302  A0F205096  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479303  A0F205094  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479304  A0F205093  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479305  A0F2F6435  2022-07-28 13:48:00   7/29/2022 18:54:48:46    Delivery
# 479306  A0F240576  2022-07-27 10:36:00  7/29/2022 18:54:56:547    Delivery
#
#         In_Qty  Out_Qty   Order No  Location
# ...

# %%
df1 = df1.dropna()
df1
# Out:
#               SKU                 Date          Complete Date  order_type   \
# 0       A0FA966A7  2021-01-04 09:27:00   1/4/2021 10:58:59:653    Delivery
# 1       A0F2AF467  2021-01-04 09:21:00    1/4/2021 10:59:00:19    Delivery
# 2       A07392036  2021-01-04 09:19:00    1/4/2021 10:59:00:56    Delivery
# 3       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# 4       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# ...           ...                  ...                     ...         ...
# 479302  A0F205096  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479303  A0F205094  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479304  A0F205093  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479305  A0F2F6435  2022-07-28 13:48:00   7/29/2022 18:54:48:46    Delivery
# 479306  A0F240576  2022-07-27 10:36:00  7/29/2022 18:54:56:547    Delivery
#
#         In_Qty  Out_Qty   Order No  Location
# ...

# %%
df1.duplicated().sum()
# Out:
# 3084

# %%
df1.shape
# Out:
# (277070, 8)

# %%
df1 = df1.drop_duplicates()
df1
# Out:
#               SKU                 Date          Complete Date  order_type   \
# 0       A0FA966A7  2021-01-04 09:27:00   1/4/2021 10:58:59:653    Delivery
# 1       A0F2AF467  2021-01-04 09:21:00    1/4/2021 10:59:00:19    Delivery
# 2       A07392036  2021-01-04 09:19:00    1/4/2021 10:59:00:56    Delivery
# 3       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# 4       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# ...           ...                  ...                     ...         ...
# 479302  A0F205096  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479303  A0F205094  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479304  A0F205093  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479305  A0F2F6435  2022-07-28 13:48:00   7/29/2022 18:54:48:46    Delivery
# 479306  A0F240576  2022-07-27 10:36:00  7/29/2022 18:54:56:547    Delivery
#
#         In_Qty  Out_Qty   Order No  Location
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273986 entries, 0 to 479306
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SKU             273986 non-null  object
#  1   Date            273986 non-null  object
#  2   Complete Date   273986 non-null  object
#  3   order_type      273986 non-null  object
#  4   In_Qty          273986 non-null  float64
#  5   Out_Qty         273986 non-null  float64
#  6   Order No        273986 non-null  object
#  7   Location        273986 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 18.8+ MB

# %%
df1.columns
# Out:
# Index(['SKU', 'Date', 'Complete Date ', 'order_type ', 'In_Qty', 'Out_Qty',
#        'Order No ', 'Location'],
#       dtype='object')

# %%
convert_dict = {'SKU': object,
                'Date': 'datetime64[ns]',
                'Complete Date ' : 'datetime64',
                'order_type ': object,
                'In_Qty':'float64',
                'Out_Qty':'float64',
                'Order No ':object,
                'Location':object 
                }

# %%
convert_dict = {
                'Complete Date ' : 'datetime64[ns]'
                }

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273986 entries, 0 to 479306
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SKU             273986 non-null  object
#  1   Date            273986 non-null  object
#  2   Complete Date   273986 non-null  object
#  3   order_type      273986 non-null  object
#  4   In_Qty          273986 non-null  float64
#  5   Out_Qty         273986 non-null  float64
#  6   Order No        273986 non-null  object
#  7   Location        273986 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 18.8+ MB

# %%
df3 = df1.iloc[:,2]  
df3
df2 = df1.iloc[:,1]

# %%
df3 = pd.DataFrame(df3)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273986 entries, 0 to 479306
# Data columns (total 1 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Complete Date   273986 non-null  object
# dtypes: object(1)
# memory usage: 4.2+ MB

# %%
df3.rename(columns = {'Complete Date ':'Complete_Date'}, inplace = True)
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
df4 = pd.concat([df1 , df3], axis=1)
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273986 entries, 0 to 479306
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SKU             273986 non-null  object
#  1   Date            273986 non-null  object
#  2   Complete Date   273986 non-null  object
#  3   order_type      273986 non-null  object
#  4   In_Qty          273986 non-null  float64
#  5   Out_Qty         273986 non-null  float64
#  6   Order No        273986 non-null  object
#  7   Location        273986 non-null  object
#  8   Complete_Date   273986 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 20.9+ MB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273986 entries, 0 to 479306
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SKU             273986 non-null  object
#  1   Date            273986 non-null  object
#  2   Complete Date   273986 non-null  object
#  3   order_type      273986 non-null  object
#  4   In_Qty          273986 non-null  float64
#  5   Out_Qty         273986 non-null  float64
#  6   Order No        273986 non-null  object
#  7   Location        273986 non-null  object
#  8   Complete_Date   273986 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 20.9+ MB

# %%
df4
# Out:
#               SKU                 Date          Complete Date  order_type   \
# 0       A0FA966A7  2021-01-04 09:27:00   1/4/2021 10:58:59:653    Delivery
# 1       A0F2AF467  2021-01-04 09:21:00    1/4/2021 10:59:00:19    Delivery
# 2       A07392036  2021-01-04 09:19:00    1/4/2021 10:59:00:56    Delivery
# 3       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# 4       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# ...           ...                  ...                     ...         ...
# 479302  A0F205096  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479303  A0F205094  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479304  A0F205093  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479305  A0F2F6435  2022-07-28 13:48:00   7/29/2022 18:54:48:46    Delivery
# 479306  A0F240576  2022-07-27 10:36:00  7/29/2022 18:54:56:547    Delivery
#
#         In_Qty  Out_Qty   Order No  Location           Complete_Date
# ...

# %%
df6 = pd.DataFrame(df1['Date'])

# %%
df6 = pd.to_datetime(df6['Date'], infer_datetime_format = True, errors = 'coerce' )

# %%
df6 = pd.DataFrame(df6)

# %%
df6.rename(columns = {'Date':'date'}, inplace = True)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 273986 entries, 0 to 479306
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    273479 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.2 MB

# %%
df5 =  pd.concat([df4, df6], axis=1)
df5
# Out:
#               SKU                 Date          Complete Date  order_type   \
# 0       A0FA966A7  2021-01-04 09:27:00   1/4/2021 10:58:59:653    Delivery
# 1       A0F2AF467  2021-01-04 09:21:00    1/4/2021 10:59:00:19    Delivery
# 2       A07392036  2021-01-04 09:19:00    1/4/2021 10:59:00:56    Delivery
# 3       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# 4       A07A77346  2021-01-04 09:13:00   1/4/2021 10:59:00:953    Delivery
# ...           ...                  ...                     ...         ...
# 479302  A0F205096  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479303  A0F205094  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479304  A0F205093  2022-07-29 16:58:00   7/29/2022 18:53:42:33    Delivery
# 479305  A0F2F6435  2022-07-28 13:48:00   7/29/2022 18:54:48:46    Delivery
# 479306  A0F240576  2022-07-27 10:36:00  7/29/2022 18:54:56:547    Delivery
#
# ...

# %%
df5 = pd.read_excel('C:/Users/DELL/Downloads/final_df.xlsx')
df5
# Out:
#         Unnamed: 0        SKU order_type   In_Qty  Out_Qty   Order No   \
# 0                0  A0FA966A7    Delivery       0        3  4079989522
# 1                1  A0F2AF467    Delivery       0        5  4079989518
# 2                2  A07392036    Delivery       0       12  4079989512
# 3                3  A07A77346    Delivery       0      240  4079989500
# 4                4  A07A77346    Delivery       0      560  4079989500
# ...            ...        ...         ...     ...      ...         ...
# 273981      479302  A0F205096    Delivery       0       20  4089919876
# 273982      479303  A0F205094    Delivery       0       80  4089919876
# 273983      479304  A0F205093    Delivery       0        5  4089919876
# 273984      479305  A0F2F6435    Delivery       0       10  4089894920
# 273985      479306  A0F240576    Delivery       0       18  4089870512
#
#        Location           Complete_Date                date
# ...

# %%
df5.info()
df5.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273986 entries, 0 to 273985
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     273986 non-null  int64
#  1   SKU            273986 non-null  object
#  2   order_type     273986 non-null  object
#  3   In_Qty         273986 non-null  int64
#  4   Out_Qty        273986 non-null  int64
#  5   Order No       273986 non-null  object
#  6   Location       273986 non-null  object
#  7   Complete_Date  273065 non-null  datetime64[ns]
#  8   date           273479 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 18.8+ MB
# Index(['Unnamed: 0', 'SKU', 'order_type ', 'In_Qty', 'Out_Qty', 'Order No ',
#        'Location', 'Complete_Date', 'date'],
#       dtype='object')

# %%
df5.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273986 entries, 0 to 273985
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   SKU            273986 non-null  object
#  1   order_type     273986 non-null  object
#  2   In_Qty         273986 non-null  int64
#  3   Out_Qty        273986 non-null  int64
#  4   Order No       273986 non-null  object
#  5   Location       273986 non-null  object
#  6   Complete_Date  273065 non-null  datetime64[ns]
#  7   date           273479 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 16.7+ MB

# %%
final_df = df5
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273986 entries, 0 to 273985
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   SKU            273986 non-null  object
#  1   order_type     273986 non-null  object
#  2   In_Qty         273986 non-null  int64
#  3   Out_Qty        273986 non-null  int64
#  4   Order No       273986 non-null  object
#  5   Location       273986 non-null  object
#  6   Complete_Date  273065 non-null  datetime64[ns]
#  7   date           273479 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 16.7+ MB

# %%
final_df.to_excel('C:/Users/DELL/Downloads/final_df.xlsx')

# %%
final_df.describe()
# Out:
#               In_Qty        Out_Qty
# count  273986.000000  273986.000000
# mean      172.391341     178.637069
# std      1527.534854     790.767399
# min         0.000000       0.000000
# 25%         0.000000       4.000000
# 50%         0.000000      20.000000
# 75%         0.000000      65.000000
# max    145400.000000   60000.000000

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273986 entries, 0 to 273985
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   SKU            273986 non-null  object
#  1   order_type     273986 non-null  object
#  2   In_Qty         273986 non-null  int64
#  3   Out_Qty        273986 non-null  int64
#  4   Order No       273986 non-null  object
#  5   Location       273986 non-null  object
#  6   Complete_Date  273065 non-null  datetime64[ns]
#  7   date           273479 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 16.7+ MB

# %%
import datetime

# %%
df_test = (df5['Complete_Date'] - df5['date'])
df_test
# Out:
# 0        0 days 01:31:59.653000
# 1        0 days 01:38:00.190000
# 2        0 days 01:40:00.560000
# 3        0 days 01:46:00.953000
# 4        0 days 01:46:00.953000
#                   ...
# 273981   0 days 01:55:42.330000
# 273982   0 days 01:55:42.330000
# 273983   0 days 01:55:42.330000
# 273984   1 days 05:06:48.460000
# 273985   2 days 08:18:56.547000
# Length: 273986, dtype: timedelta64[ns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
final_df.describe()
# Out:
#               In_Qty        Out_Qty
# count  273986.000000  273986.000000
# mean      172.391341     178.637069
# std      1527.534854     790.767399
# min         0.000000       0.000000
# 25%         0.000000       4.000000
# 50%         0.000000      20.000000
# 75%         0.000000      65.000000
# max    145400.000000   60000.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
final_df.columns
# Out:
# Index(['SKU', 'order_type ', 'In_Qty', 'Out_Qty', 'Order No ', 'Location',
#        'Complete_Date', 'date'],
#       dtype='object')

# %%
df5['order_type '].replace(['Delivery', 'Receive'],
                        [0, 1], inplace=True)
df5
# Out:
#               SKU  order_type   In_Qty  Out_Qty   Order No  Location  \
# 0       A0FA966A7            0       0        3  4079989522    D4901
# 1       A0F2AF467            0       0        5  4079989518    F4901
# 2       A07392036            0       0       12  4079989512    A5203
# 3       A07A77346            0       0      240  4079989500    F4004
# 4       A07A77346            0       0      560  4079989500    G0906
# ...           ...          ...     ...      ...         ...      ...
# 273981  A0F205096            0       0       20  4089919876    K0501
# 273982  A0F205094            0       0       80  4089919876    O0601
# 273983  A0F205093            0       0        5  4089919876    C1004
# 273984  A0F2F6435            0       0       10  4089894920    E5801
# 273985  A0F240576            0       0       18  4089870512    C0605
#
#                  Complete_Date                date
# 0      2021-01-04 10:58:59.653 2021-01-04 09:27:00
# ...

# %%
sns.countplot(x='order_type ', data = df5)

# we can see there are far more Delivery(0) transactions as compared to Recieve(1)
# Out:
# <AxesSubplot:xlabel='order_type ', ylabel='count'>

# %%
sns.pairplot(final_df)

# %%
sns.lineplot(data=df5, x="date", y="order_type ")
# Out:
# <AxesSubplot:xlabel='date', ylabel='order_type '>
